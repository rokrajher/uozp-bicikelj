# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot

df = pd.read_csv('./podatki/bicikelj_train.csv')
display(df.head(5))
# Out:
#              timestamp  PREŠERNOV TRG-PETKOVŠKOVO NABREŽJE
# 0  2022-08-02 13:04:00                                  17  \
# 1  2022-08-02 13:10:00                                  18
# 2  2022-08-02 13:14:00                                  17
# 3  2022-08-02 13:20:00                                  18
# 4  2022-08-02 13:25:00                                  20
#
#    POGAČARJEV TRG-TRŽNICA  KONGRESNI TRG-ŠUBIČEVA ULICA  CANKARJEVA UL.-NAMA
# 0                      17                            20                   26  \
# 1                      17                            19                   25
# 2                      18                            19                   25
# 3                      15                            20                   26
# 4                      16                            19                   23
#
#    BREG  GRUDNOVO NABREŽJE-KARLOVŠKA C.  MIKLOŠIČEV PARK  BAVARSKI DVOR
# 0    10                              10               16              7  \
# 1    10                              11               15              7
# 2     9                              11               16              7
# 3    12                              11               18              6
# 4    12                              10               17              6
#
#    TRG OF-KOLODVORSKA UL.  ...  POVŠETOVA - KAJUHOVA  SOSESKA NOVO BRDO
# 0                      12  ...                     9                  7  \
# 1                      12  ...                     9                  7
# 2                      12  ...                     9                  7
# 3                      13  ...                     9                  7
# 4                      15  ...                     9                  7
#
#    TEHNOLOŠKI PARK  VOJKOVA - GASILSKA BRIGADA
# 0                5                           4  \
# 1                5                           4
# 2                5                           4
# 3                5                           2
# 4                5                           2
#
#    GERBIČEVA - ŠPORTNI PARK SVOBODA  DOLENJSKA C. - STRELIŠČE
# 0                                 2                         9  \
# 1                                 1                         9
# 2                                 1                         9
# 3                                 1                         9
# 4                                 1                         9
#
#    ROŠKA - STRELIŠKA  LEK - VEROVŠKOVA  VOKA - SLOVENČEVA
# 0                  4                 8                  3  \
# 1                  4                 8                  2
# 2                  4                 8                  2
# 3                  4                 8                  2
# 4                  4                 8                  2
#
#    SUPERNOVA LJUBLJANA - RUDNIK
# 0                             1
# 1                             1
# 2                             1
# 3                             1
# 4                             1
#
# [5 rows x 84 columns]

# %%
# Convert 'timestamp' column to timestamptime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Extract day, hour, minute, and second values
df['month'] = df['timestamp'].dt.month
df['day'] = df['timestamp'].dt.day
df['hour'] = df['timestamp'].dt.hour
df['minute'] = df['timestamp'].dt.minute
df['dayofweek'] = df['timestamp'].dt.dayofweek
df['is_year_start'] = df['timestamp'].dt.is_year_start
df['is_year_end'] = df['timestamp'].dt.is_year_end
df['is_month_start'] = df['timestamp'].dt.is_month_start
df['is_month_end'] = df['timestamp'].dt.is_month_end
df['is_quarter_start'] = df['timestamp'].dt.is_quarter_start
df['is_quarter_end'] = df['timestamp'].dt.is_quarter_end






display(df.tail(20))
# Out:
#                timestamp  PREŠERNOV TRG-PETKOVŠKOVO NABREŽJE
# 7719 2022-10-01 16:43:00                                  17  \
# 7720 2022-10-01 16:47:00                                  17
# 7721 2022-10-01 16:53:00                                  18
# 7722 2022-10-01 16:57:00                                  18
# 7723 2022-10-01 17:03:00                                  20
# 7724 2022-10-01 17:07:00                                  20
# 7725 2022-10-01 17:13:00                                  20
# 7726 2022-10-01 17:17:00                                  20
# 7727 2022-10-01 17:23:00                                  20
# 7728 2022-10-01 17:26:00                                  20
# 7729 2022-10-01 17:33:00                                  18
# 7730 2022-10-01 17:43:00                                  19
# 7731 2022-10-01 17:47:00                                  17
# 7732 2022-10-01 17:54:00                                  16
# 7733 2022-10-01 17:56:00                                  16
# 7734 2022-10-01 18:03:00                                  18
# 7735 2022-10-01 18:07:00                                  20
# 7736 2022-10-01 18:13:00                                  19
# 7737 2022-10-01 18:16:00                                  19
# 7738 2022-10-01 18:23:00                                  20
#
#       POGAČARJEV TRG-TRŽNICA  KONGRESNI TRG-ŠUBIČEVA ULICA
# 7719                      12                             4  \
# 7720                      12                             4
# 7721                      13                             4
# 7722                      13                             5
# 7723                      16                             7
# 7724                      17                             7
# 7725                      15                             7
# 7726                      15                             7
# 7727                      14                             7
# 7728                      15                             7
# 7729                      18                             9
# 7730                      18                            12
# 7731                      17                            11
# 7732                      17                            11
# 7733                      17                            12
# 7734                      17                            14
# 7735                      17                            13
# 7736                      18                            14
# 7737                      17                            16
# 7738                      17                            15
#
#       CANKARJEVA UL.-NAMA  BREG  GRUDNOVO NABREŽJE-KARLOVŠKA C.
# 7719                   14    14                               5  \
# 7720                   15    13                               5
# 7721                   13    13                               5
# 7722                   15    12                               6
# 7723                   14    12                               5
# 7724                   13    12                               5
# 7725                   12    12                               5
# 7726                   13    12                               4
# 7727                   15    12                               3
# 7728                   16    13                               3
# 7729                   11    11                               3
# 7730                   11    10                               4
# 7731                   11     9                               4
# 7732                    8     9                               5
# 7733                    8     9                               5
# 7734                    7     7                               5
# 7735                    7     7                               5
# 7736                    5     8                               3
# 7737                    4     6                               3
# 7738                    3     6                               6
#
#       MIKLOŠIČEV PARK  BAVARSKI DVOR  TRG OF-KOLODVORSKA UL.  ...
# 7719               11             17                      15  ...  \
# 7720               11             19                      15  ...
# 7721               12             20                      15  ...
# 7722               13             20                      17  ...
# 7723               13             16                      17  ...
# 7724               13             16                      16  ...
# 7725               13             16                      17  ...
# 7726               13             16                      17  ...
# 7727               13             18                      20  ...
# 7728               13             17                      19  ...
# 7729               13             18                      18  ...
# 7730               13             18                      21  ...
# 7731               14             18                      23  ...
# 7732               12             18                      23  ...
# 7733               12             18                      24  ...
# 7734               10             20                      25  ...
# 7735               11             19                      24  ...
# 7736               10             20                      23  ...
# 7737                9             17                      21  ...
# 7738                9             16                      21  ...
#
#       SUPERNOVA LJUBLJANA - RUDNIK  month  day  hour  minute  dayofweek
# 7719                             7     10    1    16      43          5  \
# 7720                             7     10    1    16      47          5
# 7721                             7     10    1    16      53          5
# 7722                             7     10    1    16      57          5
# 7723                             6     10    1    17       3          5
# 7724                             6     10    1    17       7          5
# 7725                             6     10    1    17      13          5
# 7726                             6     10    1    17      17          5
# 7727                             6     10    1    17      23          5
# 7728                             6     10    1    17      26          5
# 7729                             6     10    1    17      33          5
# 7730                             6     10    1    17      43          5
# 7731                             6     10    1    17      47          5
# 7732                             7     10    1    17      54          5
# 7733                             7     10    1    17      56          5
# 7734                             7     10    1    18       3          5
# 7735                             7     10    1    18       7          5
# 7736                             7     10    1    18      13          5
# 7737                             7     10    1    18      16          5
# 7738                             7     10    1    18      23          5
#
#       is_year_start  is_month_start  is_quarter_start  is_quarter_end
# 7719          False            True              True           False
# 7720          False            True              True           False
# 7721          False            True              True           False
# 7722          False            True              True           False
# 7723          False            True              True           False
# 7724          False            True              True           False
# 7725          False            True              True           False
# 7726          False            True              True           False
# 7727          False            True              True           False
# 7728          False            True              True           False
# 7729          False            True              True           False
# 7730          False            True              True           False
# 7731          False            True              True           False
# 7732          False            True              True           False
# 7733          False            True              True           False
# 7734          False            True              True           False
# 7735          False            True              True           False
# 7736          False            True              True           False
# 7737          False            True              True           False
# 7738          False            True              True           False
#
# [20 rows x 93 columns]
